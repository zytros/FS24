# %%
import timm

def download_pretrained_swin_transformer(model_name='swin_small_patch4_window7_224'):
    model = timm.create_model(model_name, pretrained=True)
    return model

# %%
model = download_pretrained_swin_transformer()

# %%
import os
from PIL import Image
import torch
from torchvision.transforms import Compose, Resize, ToTensor, Normalize

def classify_images(folder_path, model):
    # Define the transformations
    transform = Compose([
        Resize((224, 224)),
        ToTensor(),
        Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    model.eval()

    # List all files in the folder
    for filename in os.listdir(folder_path):
        # Check if the file is an image
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            # Load and transform the image
            image_path = os.path.join(folder_path, filename)
            image = Image.open(image_path).convert('RGB')
            image = transform(image).unsqueeze(0)

            # Classify the image
            with torch.no_grad():
                output = model(image)
                _, predicted = output.max(1)

            # Print the filename and the inferred class
            print(f'{filename}: {predicted.item()}')

# %%
classify_images('data', model)
# Out:
# cat.jpeg: 285
# lemur1.jpg: 387
# lilly and sammy.jpg: 750
# lilly.jpg: 285
# lilly2.jpg: 750
# sammy1.jpg: 282

# %%
model
# Out:
# SwinTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#   )
#   (layers): Sequential(
#     (0): SwinTransformerStage(
#       (downsample): Identity()
#       (blocks): Sequential(
#         (0): SwinTransformerBlock(
#           (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=96, out_features=288, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=96, out_features=96, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=96, out_features=384, bias=True)
# ...

# %%
#understanding contributing neurons via attribution visualization
